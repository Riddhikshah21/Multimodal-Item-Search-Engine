# %%
import pandas as pd
import requests
from io import BytesIO
from PIL import Image
import torch
import open_clip
import os
from tqdm import tqdm
import numpy as np

# %%
# pip install "numpy<2" --force-reinstall

# %%
import chromadb
from chromadb.utils.embedding_functions import OpenCLIPEmbeddingFunction
from chromadb.utils.data_loaders import ImageLoader

# create a chromadb object which acts as main interface for adding collections(traditional db), docs and perform queries. 
chroma_client = chromadb.PersistentClient(path="data/pinteresty.db") #persistent client so it does not lose memory when we terminate the program

# instantiate image loader
image_loader = ImageLoader()

# instantiate multimodal embedding function
embedding_function = OpenCLIPEmbeddingFunction()

# %%
# !pip install chromadb pillow torch torchvision open_clip_torch tqdm

# %%
# create the collection, - vector database
pin_collection = chroma_client.get_or_create_collection(
    "pinteresty_collection",
    embedding_function=embedding_function,
    data_loader=image_loader,
)

# %%
df = pd.read_csv("/Users/riddhishah/Documents/GitHub/Multimodal-Item-Search-Engine/data.csv")
df.head()
# Out:
#                                                  url              post_id  \
# 0    https://www.pinterest.com/pin/17381148553849109    17381148553849109
# 1  https://www.pinterest.com/pin/1084804628983062016  1084804628983062016
# 2   https://www.pinterest.com/pin/355362226865072169   355362226865072169
# 3   https://www.pinterest.com/pin/694328467581318715   694328467581318715
# 4   https://www.pinterest.com/pin/986710599584098709   986710599584098709
#
#                                                title  \
# 0            50 DIY Dog Toys You Can Make In No Time
# 1                             Dog Toys - Snuggly Cup
# 2                                Aesthetic Dog Finds
# 3      Pup Cup Tumbler Plush Squeaker Dog Toy - Blue
# 4  The 50 Best Interactive Dog Toys for Brain Sti...
#
#                                              content  \
# 0  If your home dog buddy is not so gentle with t...
# 1  Golden Pooch Tennis Shoe Plush Dog Toy - Get t...
# 2  Shop Premium Dog Beds for Large Dogs … and oth...
# 3  Introducing the Pup Cup Tumbler Dog Toy - wher...
# 4  For pets who need brain stimulation and fight ...
#
#                   date_posted          user_name  \
# 0  "2022-06-11T00:02:08.000Z"          allyboo24
# 1  "2024-05-01T12:30:48.000Z"  lilyjaneboutique1
# 2  "2024-06-28T16:57:59.000Z"        hayleylarue
# 3  "2024-04-06T12:32:54.000Z"        miamorepets
# 4  "2022-07-22T04:23:33.000Z"         topdogtips
#
#                                       user_url              user_id  \
# 0          https://www.pinterest.com/allyboo24    17381285970317537
# 1  https://www.pinterest.com/lilyjaneboutique1  1050746294219424452
# 2        https://www.pinterest.com/hayleylarue   267049590312665613
# 3        https://www.pinterest.com/miamorepets   694328604959557638
# 4         https://www.pinterest.com/topdogtips   542050642559011518
#
#    followers  likes                                         categories  \
# 0        151      3               ["Tiere","Tiere Und Heimtierbedarf"]
# 1         73      5                                        ["Animals"]
# 2      68385     10  ["Animals","Animals And Pet Supplies","Dog Sup...
# 3        447     14                                        ["Animals"]
# 4      76098      4                                          ["Tiere"]
#
#    source                                     attached_files  \
# 0     NaN  ["https://i.pinimg.com/originals/6d/38/d7/6d38...
# 1     NaN  ["https://i.pinimg.com/originals/98/2d/85/982d...
# 2     NaN  ["https://i.pinimg.com/originals/6b/17/83/6b17...
# 3     NaN  ["https://i.pinimg.com/originals/d3/b9/25/d3b9...
# 4     NaN  ["https://i.pinimg.com/originals/28/88/11/2888...
#
#                                      image_video_url  video_length  \
# 0  https://i.pinimg.com/originals/6d/38/d7/6d38d7...             0
# 1  https://i.pinimg.com/originals/98/2d/85/982d85...             0
# 2  https://i.pinimg.com/originals/6b/17/83/6b1783...             0
# 3  https://i.pinimg.com/originals/d3/b9/25/d3b925...             0
# 4  https://i.pinimg.com/originals/28/88/11/288811...             0
#
#                                             hashtags  comments_num  \
# 0  ["Hausgemachtes Hundespielzeug","Hunde Spielze...             2
# 1  ["Makeup Dog Toys","Dog Stuff Aesthetic","Cute...             0
# 2  ["Aesthetic Dog Room Ideas","Aesthetic Dog Dec...             0
# 3  ["Things To Get Your Dog","Cute Stuff For Dogs...             2
# 4  ["Hunde Spielzeug Diy","Hündchen Übung","Hunde...             4
#
#                                             comments         discovery_input  \
# 0  ["Nice thought, but oh-no-no-no. My dog would ...  {"keyword":"dog toys"}
# 1                                                NaN  {"keyword":"dog toys"}
# 2                                                NaN  {"keyword":"dog toys"}
# 3  ["i dont think thats blue.. (check the title)"...  {"keyword":"dog toys"}
# 4  ["Looks like fun for the Dogs","Works like a k...  {"keyword":"dog toys"}
#
#   post_type
# 0     image
# 1     image
# 2     image
# 3     image
# 4     image

# %%
def load_image_from_url(url):
    try:
        resp = requests.get(url, timeout=10)
        img = Image.open(BytesIO(resp.content)).convert("RGB")
        return img
    except:
        return None

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model, _, preprocess = open_clip.create_model_and_transforms(
    model_name="ViT-B-32",
    pretrained="openai"
)
tokenizer = open_clip.get_tokenizer("ViT-B-32")
model = model.to(device)
# Out:
# /Users/riddhishah/opt/anaconda3/envs/pythonProject/lib/python3.10/site-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(

# %%
def encode_image(path):
    img = preprocess(Image.open(path).convert("RGB")).unsqueeze(0).to(device)
    with torch.no_grad():
        emb = model.encode_image(img)
    return emb.cpu().numpy()[0].tolist()

# %%
def encode_text(text):
    tokens = tokenizer([text]).to(device)
    with torch.no_grad():
        emb = model.encode_text(tokens)
    return emb.cpu().numpy()[0].tolist()

# %%
# pip install --upgrade --force-reinstall numpy
#

# %%
import numpy as np
ids = []
embeddings = []
metadatas = []

for idx, row in df.iterrows():
    url = row["image_video_url"]

    img = load_image_from_url(url)
    if img is None:
        continue

    # preprocess from OpenCLIP
    inp = preprocess(img).unsqueeze(0).to(device)
    with torch.no_grad():
        emb = model.encode_image(inp).cpu().numpy()[0].tolist()

    ids.append(str(row["post_id"]))  # or index
    embeddings.append(emb)
    metadatas.append({
        "url": url,
        "title": row["title"],
        "post_id": str(row["post_id"]),
    })

pin_collection.add(
    ids=ids,
    embeddings=embeddings,
    metadatas=metadatas
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 13
#      10     continue
#      12 # preprocess from OpenCLIP
# ---> 13 inp = preprocess(img).unsqueeze(0).to(device)
#      14 with torch.no_grad():
#      15     emb = model.encode_image(inp).cpu().numpy()[0].tolist()
#
# File ~/opt/anaconda3/envs/pythonProject/lib/python3.10/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/opt/anaconda3/envs/pythonProject/lib/python3.10/site-packages/torchvision/transforms/transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File ~/opt/anaconda3/envs/pythonProject/lib/python3.10/site-packages/torchvision/transforms/functional.py:167, in to_tensor(pic)
#     165 # handle PIL Image
#     166 mode_to_nptype = {"I": np.int32, "I;16" if sys.byteorder == "little" else "I;16B": np.int16, "F": np.float32}
# --> 167 img = torch.from_numpy(np.array(pic, mode_to_nptype.get(pic.mode, np.uint8), copy=True))
#     169 if pic.mode == "1":
#     170     img = 255 * img
#
# RuntimeError: Numpy is not available

# %%
# !pip install --force-reinstall torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
